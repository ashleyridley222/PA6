# %%
import math
import numpy as np
class calc():
    def __init__(self,input1,input2,x):
        self.input1=input1
        self.input2=input2
        self.x=x
        
    def addition(num1,num2):
        print("Addition=",num1+num2)
    def subtraction(num1,num2):
        print("Subtraction=",num1-num2)
    def multiplication(num1,num2):
        print("Multiplication=",num1*num2)
    def division(num1,num2):
        print("Division=",num1/num2)
    def exponent(num1,num2):
        print(' {} + {}='.format(num1,num2))
        print("Exponent=",num1**num2)
    def tan(x):
        print("Tan=", math.tan(x))
    def sin(x):
        print("Sin=", math.sin(x))
    def cos(x):
        print("Cosine=",math.cos(x))   
    def factorial(x):
        print("Factorial=",math.factorial(x)) 
    def log(x):
        print("Log=",math.log(x))
    def inversion(x):
        print("Inversion=",np.invert(x))
    def floor_division(num1,num2):
        print("Floor division=",num1//num2)
    def radian_to_degree(num1,num2):
        pi=22/7
        degree=radian*(180/pi)
        print("Radians to Degree's=",degree)
    def degree_to_radian(num1,num2):
        print("Degree to Radian's=",math.radians(degree))
    def log_10(x):
        print("Base 10 logarithm=", math.log10(x))
while True:
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")    
    print("5. Exponent")
    print("6. Tan")
    print("7. Sin")
    print("8. Cosine")    
    print("9. Factorial")
    print("10. Logorithm")
    print("11. Invert")
    print("12 Floor Division")    
    print("13. Radians to Degree")
    print("14. Degree to Radian")
    print("15. Base 10 Logarithm")
    print("16. Exit")
    choice=int(input("Enter your choice(1-16):"))   
       
    if choice==1:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        calc.addition(num1,num2)


    elif choice==2:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        calc.subtraction(num1,num2)
    
    elif choice==3:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        calc.multiplication(num1,num2)
    
    elif choice==4:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        if num2 == 0:
            print('Infinity')
        else:
            calc.division(num1,num2)
    
    elif choice==5:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        calc.exponent(num1,num2)
    elif choice==6:
        x=int(input("Enter the value for Tan:")) 
        calc.tan(x)
    elif choice==7:
        x = int(input("Enter the value for Sin: "))
        calc.sin(x)
    elif choice==8:
        x = int(input("Enter the value for Cos: ")) 
        calc.cos(x) 
        
    elif choice==9:
        x = int(input("Enter the value for Factorial: "))
        calc.factorial(x) 
    elif choice==10:
        x = int(input("Enter the value for log: "))
        calc.log(x)
    elif choice==11:
        x = int(input("Enter the value for Inversion: ")) 
        calc.inversion(x)
    elif choice==12:  
        num1= int(input("Enter the value for your first number: ")) 
        num2=int(input("Enter the value for your second number: ")) 
        calc.floor_division(num1,num2)
    elif choice==13:
        radian = float(input("Input radians: "))
        calc.radian_to_degree(num1,num2)
    elif choice== 14:
        degree=int(input("Enter the degree: "))
        calc.degree_to_radian(num1,num2)
    elif choice== 15:
        x = int(input("Enter the value for log: ")) 
        calc.log_10(x)
    elif choice==16:
        break
    else:
        print("Wrong Choice")
# Out:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exponent
# 6. Tan
# 7. Sin
# 8. Cosine
# 9. Factorial
# 10. Logorithm
# 11. Invert
# 12 Floor Division
# 13. Radians to Degree
# 14. Degree to Radian
# 15. Base 10 Logarithm
# 16. Exit
# Enter your choice(1-16):5
# Enter 1st Number:1
# Enter 2nd Number:2
#  1 + 2=
# Exponent= 1
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exponent
# 6. Tan
# 7. Sin
# 8. Cosine
# 9. Factorial
# 10. Logorithm
# 11. Invert
# 12 Floor Division
# 13. Radians to Degree
# 14. Degree to Radian
# 15. Base 10 Logarithm
# 16. Exit
# Enter your choice(1-16):6
# Enter the value for Tan:12
# Tan= -0.6358599286615807
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exponent
# 6. Tan
# 7. Sin
# 8. Cosine
# 9. Factorial
# 10. Logorithm
# 11. Invert
# 12 Floor Division
# 13. Radians to Degree
# 14. Degree to Radian
# 15. Base 10 Logarithm
# 16. Exit
# Enter your choice(1-16):7
# ...
